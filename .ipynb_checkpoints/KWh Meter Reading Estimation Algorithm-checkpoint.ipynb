# %%
import matplotlib.pyplot as plt
import pandas as pd
import csv

data = pd.read_csv('data_kwh.csv')
data.head()
# Out:
#    SerialNumber  NoRecord DateTime  ExportWhTotal  ImportWhTotal  \
# 0    3141880190       NaN  00:00.0     40031250.0              0
# 1    3141880190       NaN  30:00.0     38718750.0              0
# 2    3141880190       NaN  00:00.0     37437500.0              0
# 3    3141880190       NaN  30:00.0     36000000.0              0
# 4    3141880190       NaN  00:00.0     34843750.0              0
#
#    ExportVarhTotal  ImportVarhTotal  ExportVAhTotal  ImportVAhTotal  \
# 0              NaN              NaN             NaN             NaN
# 1              NaN              NaN             NaN             NaN
# 2              NaN              NaN             NaN             NaN
# 3              NaN              NaN             NaN             NaN
# 4              NaN              NaN             NaN             NaN
#
#    AvgVoltPh-A  ...  AvgPFPhB  AvgPFPhC  Spare2  Spare3  ExportWPh-A  \
# 0          NaN  ...       NaN       NaN     NaN     NaN          NaN
# ...

# %%
y = data['ExportWhTotal'].head(5000).tolist()
z = []
for data in y:
    if data > 0:
        if data < 100000000:
            z.append(data)
x = list(range(0, len(z)))

# %%
f = plt.figure()
f.set_figwidth(50)
f.set_figheight(30)
p = plt.plot(x, z)
